# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 78
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 78:
# Image - Min Value: 2 Max Value: 247
# Image - Shape: (32, 32, 3)
# Label - Label Id: 3 Name: cat

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
import numpy as np

def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x = np.array(x)
    x_norm = x/x.max()
    return x_norm

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
from sklearn.preprocessing import LabelBinarizer

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    x_one_hot = np.zeros((len(x), 10))
    for i in range(len(x)):
        x_one_hot[i,x[i]] = 1
        
    return x_one_hot



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    image_shape = list(image_shape)
    return tf.placeholder(tf.float32, 
                          shape=[None, image_shape[0], image_shape[1], image_shape[2]], 
                          name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, 
                          shape=[None, n_classes], 
                          name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,
                          shape=None,
                          name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # Preprocessing
    batch_size, image_height, image_width, channels = x_tensor.get_shape().as_list()
    
    # Convolution layer                   
    conv_layer = tf.nn.conv2d(
        input = x_tensor,
        filter = tf.Variable(tf.truncated_normal(list(conv_ksize)+[channels, conv_num_outputs])),
        strides = [1]+list(conv_strides)+[1],
        padding = 'SAME'
    )
    
    conv_layer = tf.nn.bias_add(
        value = conv_layer,
        bias = tf.Variable(tf.zeros(conv_num_outputs))
    )
    
    conv_layer = tf.nn.relu(conv_layer)
    
    # Pooling layer
    maxpool_layer = tf.nn.max_pool(
        value = conv_layer,
        ksize = [1]+list(pool_ksize)+[1],
        strides = [1]+list(pool_strides)+[1],
        padding = 'SAME'
    )
    
    return maxpool_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    batch_size, image_height, image_width, channels = x_tensor.get_shape().as_list()
    flatten_layer = tf.reshape(
        tensor = x_tensor,
        shape = [-1, image_height*image_width*channels]
    )
    
    return flatten_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    batch_size, other = x_tensor.get_shape().as_list()

    weight = tf.Variable(tf.truncated_normal(
       shape = [other, num_outputs])
    )
    
    bias = tf.Variable(tf.zeros(num_outputs))

    full_layer = tf.add(tf.matmul(x_tensor, weight), bias)
    full_layer = tf.nn.relu(full_layer)
    
    return full_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    batch_size, other = x_tensor.get_shape().as_list()

    weight = tf.Variable(tf.truncated_normal(
       shape = [other, num_outputs])
    )
    
    bias = tf.Variable(tf.zeros(num_outputs))
       
    output_layer = tf.add(tf.matmul(x_tensor, weight), bias)
    
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_nn = conv2d_maxpool(
       x_tensor = x,
       conv_num_outputs = 96,
       conv_ksize = (5,5),
       conv_strides = (2,2),
       pool_ksize = (3, 3),
       pool_strides = (2,2)
    )
    
    conv_nn = conv2d_maxpool(
       x_tensor = x,
       conv_num_outputs = 128,
       conv_ksize = (3,3),
       conv_strides = (2,2),
       pool_ksize = (3, 3),
       pool_strides = (2,2)
    )
    
    conv_nn = tf.nn.dropout(conv_nn, keep_prob)
    
    conv_nn = conv2d_maxpool(
       x_tensor = x,
       conv_num_outputs = 256,
       conv_ksize = (3,3),
       conv_strides = (2,2),
       pool_ksize = (3, 3),
       pool_strides = (2,2)
    )
    
     
        
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    conv_nn = flatten(conv_nn)
    
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    conv_nn = fully_conn(
       x_tensor = conv_nn,
       num_outputs = 2000
    )

    conv_nn = fully_conn(
       x_tensor = conv_nn,
       num_outputs = 2000
    )
    
   
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    conv_nn = output(
       x_tensor = conv_nn,
       num_outputs = 10
    )
    
    # TODO: return output
    return conv_nn


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# For CNN architecture design, I took reference of a paper:
#
# https://arxiv.org/ftp/arxiv/papers/1512/1512.00242.pdf

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})

    return None


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    
    loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})
    
    valid_accuracy = sess.run(accuracy, feed_dict={
                x: valid_features,
                y: valid_labels,
                keep_prob: 1.0})
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss, valid_accuracy))
    
    return None

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 60
batch_size = 128
keep_probability = 0.8

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 24584.8828 Validation Accuracy: 0.329600
# Epoch  2, CIFAR-10 Batch 1:  Loss: 15631.7529 Validation Accuracy: 0.345800
# Epoch  3, CIFAR-10 Batch 1:  Loss:  9760.8105 Validation Accuracy: 0.391800
# Epoch  4, CIFAR-10 Batch 1:  Loss:  6908.3281 Validation Accuracy: 0.420200
# Epoch  5, CIFAR-10 Batch 1:  Loss:  5145.9639 Validation Accuracy: 0.401000
# Epoch  6, CIFAR-10 Batch 1:  Loss:  4703.5586 Validation Accuracy: 0.429600
# Epoch  7, CIFAR-10 Batch 1:  Loss:  5088.3359 Validation Accuracy: 0.409600
# Epoch  8, CIFAR-10 Batch 1:  Loss:  3589.1133 Validation Accuracy: 0.393200
# Epoch  9, CIFAR-10 Batch 1:  Loss:  3994.7603 Validation Accuracy: 0.437200
# Epoch 10, CIFAR-10 Batch 1:  Loss:  2564.6045 Validation Accuracy: 0.429200
# Epoch 11, CIFAR-10 Batch 1:  Loss:  1376.0669 Validation Accuracy: 0.485800
# Epoch 12, CIFAR-10 Batch 1:  Loss:  1329.6030 Validation Accuracy: 0.459000
# Epoch 13, CIFAR-10 Batch 1:  Loss:  3732.4155 Validation Accuracy: 0.405800
# Epoch 14, CIFAR-10 Batch 1:  Loss:  1699.8113 Validation Accuracy: 0.431600
# Epoch 15, CIFAR-10 Batch 1:  Loss:  1600.7042 Validation Accuracy: 0.429200
# Epoch 16, CIFAR-10 Batch 1:  Loss:  1652.0551 Validation Accuracy: 0.407800
# Epoch 17, CIFAR-10 Batch 1:  Loss:   475.9237 Validation Accuracy: 0.478600
# Epoch 18, CIFAR-10 Batch 1:  Loss:  1200.7617 Validation Accuracy: 0.415200
# Epoch 19, CIFAR-10 Batch 1:  Loss:    66.4064 Validation Accuracy: 0.423000
# Epoch 20, CIFAR-10 Batch 1:  Loss:   622.5948 Validation Accuracy: 0.485800
# Epoch 21, CIFAR-10 Batch 1:  Loss:  2070.8708 Validation Accuracy: 0.451800
# Epoch 22, CIFAR-10 Batch 1:  Loss:   740.1816 Validation Accuracy: 0.493600
# Epoch 23, CIFAR-10 Batch 1:  Loss:   555.2279 Validation Accuracy: 0.499200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.517800
# Epoch 25, CIFAR-10 Batch 1:  Loss:    65.2395 Validation Accuracy: 0.488200
# Epoch 26, CIFAR-10 Batch 1:  Loss:   256.0846 Validation Accuracy: 0.474400
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.508800
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.521600
# Epoch 29, CIFAR-10 Batch 1:  Loss:   164.2549 Validation Accuracy: 0.497800
# Epoch 30, CIFAR-10 Batch 1:  Loss:   266.0718 Validation Accuracy: 0.483800
# Epoch 31, CIFAR-10 Batch 1:  Loss:   225.1198 Validation Accuracy: 0.470600
# Epoch 32, CIFAR-10 Batch 1:  Loss:   777.0798 Validation Accuracy: 0.471400
# Epoch 33, CIFAR-10 Batch 1:  Loss:   159.1334 Validation Accuracy: 0.498200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.514800
# Epoch 35, CIFAR-10 Batch 1:  Loss:    48.6537 Validation Accuracy: 0.510200
# Epoch 36, CIFAR-10 Batch 1:  Loss:   698.2768 Validation Accuracy: 0.482200
# Epoch 37, CIFAR-10 Batch 1:  Loss:   180.9319 Validation Accuracy: 0.483400
# Epoch 38, CIFAR-10 Batch 1:  Loss:   262.5067 Validation Accuracy: 0.507200
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.530600
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.541800
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.520200
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.531200
# Epoch 43, CIFAR-10 Batch 1:  Loss:   242.0387 Validation Accuracy: 0.519600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.513800
# Epoch 45, CIFAR-10 Batch 1:  Loss:   270.4482 Validation Accuracy: 0.491200
# Epoch 46, CIFAR-10 Batch 1:  Loss:   292.1592 Validation Accuracy: 0.521600
# Epoch 47, CIFAR-10 Batch 1:  Loss:   522.9777 Validation Accuracy: 0.518600
# Epoch 48, CIFAR-10 Batch 1:  Loss:   100.9146 Validation Accuracy: 0.530800
# Epoch 49, CIFAR-10 Batch 1:  Loss:    14.7637 Validation Accuracy: 0.510400
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.537200
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.522200
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.540000
# Epoch 53, CIFAR-10 Batch 1:  Loss:   123.6961 Validation Accuracy: 0.536400
# Epoch 54, CIFAR-10 Batch 1:  Loss:    86.3316 Validation Accuracy: 0.506200
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.528600
# Epoch 56, CIFAR-10 Batch 1:  Loss:   131.0705 Validation Accuracy: 0.509000
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.522600
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.524400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.544000
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.522000

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
# Reset parameters to save computational resources (based on the previous results)
epochs = 50
batch_size = 128
keep_probability = 0.8

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 26014.2793 Validation Accuracy: 0.307400
# Epoch  1, CIFAR-10 Batch 2:  Loss: 22939.5137 Validation Accuracy: 0.310600
# Epoch  1, CIFAR-10 Batch 3:  Loss: 10964.8584 Validation Accuracy: 0.377200
# Epoch  1, CIFAR-10 Batch 4:  Loss: 15935.0059 Validation Accuracy: 0.354600
# Epoch  1, CIFAR-10 Batch 5:  Loss: 12472.5859 Validation Accuracy: 0.409800
# Epoch  2, CIFAR-10 Batch 1:  Loss: 12036.4053 Validation Accuracy: 0.416800
# Epoch  2, CIFAR-10 Batch 2:  Loss: 12140.6572 Validation Accuracy: 0.399200
# Epoch  2, CIFAR-10 Batch 3:  Loss:  7496.8486 Validation Accuracy: 0.420000
# Epoch  2, CIFAR-10 Batch 4:  Loss:  5803.0142 Validation Accuracy: 0.449400
# Epoch  2, CIFAR-10 Batch 5:  Loss:  5765.7876 Validation Accuracy: 0.471600
# Epoch  3, CIFAR-10 Batch 1:  Loss: 10710.9238 Validation Accuracy: 0.447000
# Epoch  3, CIFAR-10 Batch 2:  Loss:  4916.9189 Validation Accuracy: 0.460400
# Epoch  3, CIFAR-10 Batch 3:  Loss:  3491.6353 Validation Accuracy: 0.446200
# Epoch  3, CIFAR-10 Batch 4:  Loss:  3623.0840 Validation Accuracy: 0.455600
# Epoch  3, CIFAR-10 Batch 5:  Loss:  2460.2236 Validation Accuracy: 0.501800
# Epoch  4, CIFAR-10 Batch 1:  Loss:  6114.7720 Validation Accuracy: 0.479600
# Epoch  4, CIFAR-10 Batch 2:  Loss:  5491.5830 Validation Accuracy: 0.467400
# Epoch  4, CIFAR-10 Batch 3:  Loss:  2508.2515 Validation Accuracy: 0.503400
# Epoch  4, CIFAR-10 Batch 4:  Loss:  2874.6470 Validation Accuracy: 0.480800
# Epoch  4, CIFAR-10 Batch 5:  Loss:  3977.6411 Validation Accuracy: 0.459800
# Epoch  5, CIFAR-10 Batch 1:  Loss:  5396.2920 Validation Accuracy: 0.459200
# Epoch  5, CIFAR-10 Batch 2:  Loss:  2304.5657 Validation Accuracy: 0.508400
# Epoch  5, CIFAR-10 Batch 3:  Loss:  1274.1992 Validation Accuracy: 0.514400
# Epoch  5, CIFAR-10 Batch 4:  Loss:  2707.5293 Validation Accuracy: 0.453000
# Epoch  5, CIFAR-10 Batch 5:  Loss:  1666.4824 Validation Accuracy: 0.509400
# Epoch  6, CIFAR-10 Batch 1:  Loss:  4185.2485 Validation Accuracy: 0.524000
# Epoch  6, CIFAR-10 Batch 2:  Loss:  2785.6008 Validation Accuracy: 0.517400
# Epoch  6, CIFAR-10 Batch 3:  Loss:  1163.1615 Validation Accuracy: 0.491800
# Epoch  6, CIFAR-10 Batch 4:  Loss:  2384.2319 Validation Accuracy: 0.513200
# Epoch  6, CIFAR-10 Batch 5:  Loss:  1189.8489 Validation Accuracy: 0.516200
# Epoch  7, CIFAR-10 Batch 1:  Loss:  3282.4446 Validation Accuracy: 0.513400
# Epoch  7, CIFAR-10 Batch 2:  Loss:  4060.2571 Validation Accuracy: 0.500800
# Epoch  7, CIFAR-10 Batch 3:  Loss:   858.5490 Validation Accuracy: 0.511400
# Epoch  7, CIFAR-10 Batch 4:  Loss:  1604.2627 Validation Accuracy: 0.526200
# Epoch  7, CIFAR-10 Batch 5:  Loss:   987.0032 Validation Accuracy: 0.535800
# Epoch  8, CIFAR-10 Batch 1:  Loss:  1621.2332 Validation Accuracy: 0.554800
# Epoch  8, CIFAR-10 Batch 2:  Loss:  1076.0659 Validation Accuracy: 0.526400
# Epoch  8, CIFAR-10 Batch 3:  Loss:  1037.0231 Validation Accuracy: 0.508600
# Epoch  8, CIFAR-10 Batch 4:  Loss:  1186.3347 Validation Accuracy: 0.543400
# Epoch  8, CIFAR-10 Batch 5:  Loss:  1168.0880 Validation Accuracy: 0.490000
# Epoch  9, CIFAR-10 Batch 1:  Loss:  1382.0618 Validation Accuracy: 0.520400
# Epoch  9, CIFAR-10 Batch 2:  Loss:  1538.4956 Validation Accuracy: 0.507600
# Epoch  9, CIFAR-10 Batch 3:  Loss:   694.9691 Validation Accuracy: 0.547800
# Epoch  9, CIFAR-10 Batch 4:  Loss:  1075.7281 Validation Accuracy: 0.551200
# Epoch  9, CIFAR-10 Batch 5:  Loss:  1326.3264 Validation Accuracy: 0.480800
# Epoch 10, CIFAR-10 Batch 1:  Loss:  1965.5496 Validation Accuracy: 0.493600
# Epoch 10, CIFAR-10 Batch 2:  Loss:  1861.0352 Validation Accuracy: 0.497800
# Epoch 10, CIFAR-10 Batch 3:  Loss:   696.4909 Validation Accuracy: 0.532400
# Epoch 10, CIFAR-10 Batch 4:  Loss:   361.1426 Validation Accuracy: 0.549800
# Epoch 10, CIFAR-10 Batch 5:  Loss:   747.6552 Validation Accuracy: 0.551800
# Epoch 11, CIFAR-10 Batch 1:  Loss:   919.7467 Validation Accuracy: 0.565400
# Epoch 11, CIFAR-10 Batch 2:  Loss:   845.9730 Validation Accuracy: 0.523000
# Epoch 11, CIFAR-10 Batch 3:  Loss:   379.8163 Validation Accuracy: 0.485800
# Epoch 11, CIFAR-10 Batch 4:  Loss:   601.3726 Validation Accuracy: 0.516400
# Epoch 11, CIFAR-10 Batch 5:  Loss:   535.6505 Validation Accuracy: 0.527600
# Epoch 12, CIFAR-10 Batch 1:  Loss:   844.7433 Validation Accuracy: 0.540800
# Epoch 12, CIFAR-10 Batch 2:  Loss:   335.4492 Validation Accuracy: 0.554400
# Epoch 12, CIFAR-10 Batch 3:  Loss:   275.9771 Validation Accuracy: 0.525600
# Epoch 12, CIFAR-10 Batch 4:  Loss:   500.2087 Validation Accuracy: 0.510000
# Epoch 12, CIFAR-10 Batch 5:  Loss:   276.9922 Validation Accuracy: 0.548200
# Epoch 13, CIFAR-10 Batch 1:  Loss:   694.7892 Validation Accuracy: 0.560200
# Epoch 13, CIFAR-10 Batch 2:  Loss:   249.8359 Validation Accuracy: 0.556600
# Epoch 13, CIFAR-10 Batch 3:  Loss:    15.2942 Validation Accuracy: 0.553400
# Epoch 13, CIFAR-10 Batch 4:  Loss:   324.2342 Validation Accuracy: 0.560800
# Epoch 13, CIFAR-10 Batch 5:  Loss:    93.5421 Validation Accuracy: 0.546000
# Epoch 14, CIFAR-10 Batch 1:  Loss:   901.7977 Validation Accuracy: 0.549000
# Epoch 14, CIFAR-10 Batch 2:  Loss:   419.9976 Validation Accuracy: 0.532600
# Epoch 14, CIFAR-10 Batch 3:  Loss:   406.9605 Validation Accuracy: 0.569000
# Epoch 14, CIFAR-10 Batch 4:  Loss:    91.3049 Validation Accuracy: 0.565800
# Epoch 14, CIFAR-10 Batch 5:  Loss:   171.7098 Validation Accuracy: 0.556600
# Epoch 15, CIFAR-10 Batch 1:  Loss:   333.1563 Validation Accuracy: 0.581400
# Epoch 15, CIFAR-10 Batch 2:  Loss:    84.2511 Validation Accuracy: 0.563200
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.575000
# Epoch 15, CIFAR-10 Batch 4:  Loss:   162.1826 Validation Accuracy: 0.544200
# Epoch 15, CIFAR-10 Batch 5:  Loss:   169.0948 Validation Accuracy: 0.568200
# Epoch 16, CIFAR-10 Batch 1:  Loss:   398.6208 Validation Accuracy: 0.568600
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.579600
# Epoch 16, CIFAR-10 Batch 3:  Loss:    57.0682 Validation Accuracy: 0.567000
# Epoch 16, CIFAR-10 Batch 4:  Loss:    81.4935 Validation Accuracy: 0.546000
# Epoch 16, CIFAR-10 Batch 5:  Loss:   295.9709 Validation Accuracy: 0.560400
# Epoch 17, CIFAR-10 Batch 1:  Loss:   284.7608 Validation Accuracy: 0.579000
# Epoch 17, CIFAR-10 Batch 2:  Loss:    96.3737 Validation Accuracy: 0.536200
# Epoch 17, CIFAR-10 Batch 3:  Loss:    48.9778 Validation Accuracy: 0.554800
# Epoch 17, CIFAR-10 Batch 4:  Loss:    90.3870 Validation Accuracy: 0.559200
# Epoch 17, CIFAR-10 Batch 5:  Loss:    28.7307 Validation Accuracy: 0.546000
# Epoch 18, CIFAR-10 Batch 1:  Loss:   259.7368 Validation Accuracy: 0.562600
# Epoch 18, CIFAR-10 Batch 2:  Loss:   107.0240 Validation Accuracy: 0.535400
# Epoch 18, CIFAR-10 Batch 3:  Loss:    66.3649 Validation Accuracy: 0.556000
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.580800
# Epoch 18, CIFAR-10 Batch 5:  Loss:    36.4885 Validation Accuracy: 0.563800
# Epoch 19, CIFAR-10 Batch 1:  Loss:   200.0248 Validation Accuracy: 0.580000
# Epoch 19, CIFAR-10 Batch 2:  Loss:     7.0275 Validation Accuracy: 0.578400
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.588200
# Epoch 19, CIFAR-10 Batch 4:  Loss:   158.4011 Validation Accuracy: 0.568200
# Epoch 19, CIFAR-10 Batch 5:  Loss:    27.7426 Validation Accuracy: 0.583000
# Epoch 20, CIFAR-10 Batch 1:  Loss:   216.0203 Validation Accuracy: 0.574800
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.570000
# Epoch 20, CIFAR-10 Batch 3:  Loss:    78.3776 Validation Accuracy: 0.585600
# Epoch 20, CIFAR-10 Batch 4:  Loss:    35.8189 Validation Accuracy: 0.598600
# Epoch 20, CIFAR-10 Batch 5:  Loss:   122.5316 Validation Accuracy: 0.578400
# Epoch 21, CIFAR-10 Batch 1:  Loss:    62.1096 Validation Accuracy: 0.580200
# Epoch 21, CIFAR-10 Batch 2:  Loss:    36.9645 Validation Accuracy: 0.562200
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.585200
# Epoch 21, CIFAR-10 Batch 4:  Loss:    21.0026 Validation Accuracy: 0.579200
# Epoch 21, CIFAR-10 Batch 5:  Loss:    26.7384 Validation Accuracy: 0.564000
# Epoch 22, CIFAR-10 Batch 1:  Loss:    53.2855 Validation Accuracy: 0.592400
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.568800
# Epoch 22, CIFAR-10 Batch 3:  Loss:    17.4329 Validation Accuracy: 0.576000
# Epoch 22, CIFAR-10 Batch 4:  Loss:    13.0065 Validation Accuracy: 0.598400
# Epoch 22, CIFAR-10 Batch 5:  Loss:    22.1263 Validation Accuracy: 0.572000
# Epoch 23, CIFAR-10 Batch 1:  Loss:    22.9863 Validation Accuracy: 0.609400
# Epoch 23, CIFAR-10 Batch 2:  Loss:     6.2208 Validation Accuracy: 0.569400
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.584400
# Epoch 23, CIFAR-10 Batch 4:  Loss:    56.6894 Validation Accuracy: 0.589800
# Epoch 23, CIFAR-10 Batch 5:  Loss:     8.3614 Validation Accuracy: 0.589600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.596400
# Epoch 24, CIFAR-10 Batch 2:  Loss:    31.2502 Validation Accuracy: 0.571400
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.597200
# Epoch 24, CIFAR-10 Batch 4:  Loss:    22.3570 Validation Accuracy: 0.585600
# Epoch 24, CIFAR-10 Batch 5:  Loss:     7.0865 Validation Accuracy: 0.564800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.590600
# Epoch 25, CIFAR-10 Batch 2:  Loss:    11.6117 Validation Accuracy: 0.553400
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.590400
# Epoch 25, CIFAR-10 Batch 4:  Loss:    16.9754 Validation Accuracy: 0.573400
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.573600
# Epoch 26, CIFAR-10 Batch 1:  Loss:    44.5671 Validation Accuracy: 0.567600
# Epoch 26, CIFAR-10 Batch 2:  Loss:     3.1580 Validation Accuracy: 0.587600
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.594200
# Epoch 26, CIFAR-10 Batch 4:  Loss:    54.6331 Validation Accuracy: 0.582800
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.582600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.583600
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.586600
# Epoch 27, CIFAR-10 Batch 3:  Loss:    25.7792 Validation Accuracy: 0.589200
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.594000
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.580400
# Epoch 28, CIFAR-10 Batch 1:  Loss:     3.9076 Validation Accuracy: 0.579600
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.606200
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.597600
# Epoch 28, CIFAR-10 Batch 4:  Loss:   149.7209 Validation Accuracy: 0.569000
# Epoch 28, CIFAR-10 Batch 5:  Loss:     7.8231 Validation Accuracy: 0.582200
# Epoch 29, CIFAR-10 Batch 1:  Loss:    28.7987 Validation Accuracy: 0.596800
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.593200
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.596400
# Epoch 29, CIFAR-10 Batch 4:  Loss:     5.2070 Validation Accuracy: 0.575200
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.597400
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.602600
# Epoch 30, CIFAR-10 Batch 2:  Loss:     5.2516 Validation Accuracy: 0.587000
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.586400
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.572600
# Epoch 30, CIFAR-10 Batch 5:  Loss:    23.7678 Validation Accuracy: 0.579600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.597400
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.588200
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.601200
# Epoch 31, CIFAR-10 Batch 4:  Loss:    23.9225 Validation Accuracy: 0.540800
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.595400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.589800
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.580400
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.613400
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.587800
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.593400
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.602800
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.595200
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.594800
# Epoch 33, CIFAR-10 Batch 4:  Loss:    46.6796 Validation Accuracy: 0.578800
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.593600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.613000
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.592600
# Epoch 34, CIFAR-10 Batch 3:  Loss:    23.9511 Validation Accuracy: 0.603400
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.597000
# Epoch 34, CIFAR-10 Batch 5:  Loss:     3.3540 Validation Accuracy: 0.599200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     3.1499 Validation Accuracy: 0.614200
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.607600
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.601800
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.594600
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.612600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.604600
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.601800
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.597200
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.579600
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.595200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.613600
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.608400
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.612400
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.603400
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.608400
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.613000
# Epoch 38, CIFAR-10 Batch 2:  Loss:    33.2895 Validation Accuracy: 0.602000
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.607200
# Epoch 38, CIFAR-10 Batch 4:  Loss:    33.5726 Validation Accuracy: 0.593400
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.607200
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.614200
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.598400
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.606600
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.598000
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.615200
# Epoch 40, CIFAR-10 Batch 1:  Loss:     2.3401 Validation Accuracy: 0.616800
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.597000
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.621200
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.606400
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.595200
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.618400
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.584000
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.624400
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.610600
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.620800
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.609000
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.587800
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.624000
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.610400
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.624600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.608800
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.598200
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.607200
# Epoch 43, CIFAR-10 Batch 4:  Loss:     7.4642 Validation Accuracy: 0.583600
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.614600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.620600
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.595000
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.620200
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.600400
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.628600
# Epoch 45, CIFAR-10 Batch 1:  Loss:     7.1666 Validation Accuracy: 0.628000
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.613000
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.611000
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.614800
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.616200
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.622600
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.604400
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.624600
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.607400
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.632000
# Epoch 47, CIFAR-10 Batch 1:  Loss:    15.6350 Validation Accuracy: 0.622800
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.628400
# Epoch 47, CIFAR-10 Batch 3:  Loss:     3.1798 Validation Accuracy: 0.625800
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.592600
# Epoch 47, CIFAR-10 Batch 5:  Loss:    14.6085 Validation Accuracy: 0.618800
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.616000
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.605400
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.617400
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.617200
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.625200
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.622400
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.616400
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.628800
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.618800
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.622800
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.636800
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.627600
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.617800
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.613600
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.620800

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.615506329113924

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
